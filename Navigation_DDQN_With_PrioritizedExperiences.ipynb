# %% [markdown]
# # Navigation
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the first project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893).
#
# ### 1. Start the Environment
#
# We begin by importing some necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Banana.app"`
# - **Windows** (x86): `"path/to/Banana_Windows_x86/Banana.exe"`
# - **Windows** (x86_64): `"path/to/Banana_Windows_x86_64/Banana.exe"`
# - **Linux** (x86): `"path/to/Banana_Linux/Banana.x86"`
# - **Linux** (x86_64): `"path/to/Banana_Linux/Banana.x86_64"`
# - **Linux** (x86, headless): `"path/to/Banana_Linux_NoVis/Banana.x86"`
# - **Linux** (x86_64, headless): `"path/to/Banana_Linux_NoVis/Banana.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Banana.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Banana.app")
# ```

# %%
#env = UnityEnvironment(file_name="Banana_Linux/Banana.x86_64")
env = UnityEnvironment(file_name="Banana.app")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]
brain

# %%
import torch
from lib.agents import AgentExerperienceReplay, AgentPrioritizedExperience

from lib.dqn import dqn

import matplotlib.pyplot as plt
# %matplotlib inline
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
print('States look like:', state)
state_size = len(state)
print('States have length:', state_size)

agent = AgentPrioritizedExperience(state_size=state_size, action_size=action_size, seed=0, 
                                   prioritized_experience=True, 
                                   compute_weights=True,
                                   dueling_nn=False)

scores = dqn(env, brain_name, agent, n_episodes=2000, checkpoint=13)

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

agent.save_model('ddqn_with_prioritized_experiences_qnetwork')
# Out:
# Number of agents: 1
# Number of actions: 4
# States look like: [1.         0.         0.         0.         0.84408134 0.
#  0.         1.         0.         0.0748472  0.         1.
#  0.         0.         0.25755    1.         0.         0.
#  0.         0.74177343 0.         1.         0.         0.
#  0.25854847 0.         0.         1.         0.         0.09355672
#  0.         1.         0.         0.         0.31969345 0.
#  0.        ]
# States have length: 37
# Episode 11	Average Score: -0.36

# %%
import torch
from lib.agents import AgentExerperienceReplay, AgentPrioritizedExperience

from lib.dqn import dqn

import matplotlib.pyplot as plt
# %matplotlib inline
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
print('States look like:', state)
state_size = len(state)
print('States have length:', state_size)

agent = AgentPrioritizedExperience(state_size=state_size, action_size=action_size, seed=0, 
                                   prioritized_experience=True, 
                                   compute_weights=True,
                                   dueling_nn=False)

scores = dqn(env, brain_name, agent, n_episodes=4000, checkpoint=13)









# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Episode 3316	Average Score: 14.90
# Environment solved in 3216 episodes!	Average Score: 14.90
# Episode 3317	Average Score: 14.94
# Environment solved in 3217 episodes!	Average Score: 14.94
# Episode 3318	Average Score: 14.99
# Environment solved in 3218 episodes!	Average Score: 14.99
# Episode 3319	Average Score: 15.00
# Environment solved in 3219 episodes!	Average Score: 15.00
# Episode 3321	Average Score: 15.01
# Environment solved in 3221 episodes!	Average Score: 15.01
# Episode 3322	Average Score: 15.10
# Environment solved in 3222 episodes!	Average Score: 15.10
# Episode 3323	Average Score: 15.17
# Environment solved in 3223 episodes!	Average Score: 15.17
# Episode 3324	Average Score: 15.23
# Environment solved in 3224 episodes!	Average Score: 15.23
# Episode 3400	Average Score: 14.42
# Episode 3500	Average Score: 13.93
# Episode 3600	Average Score: 14.49
# Episode 3700	Average Score: 13.75
# Episode 3800	Average Score: 14.05
# Episode 3893	Average Score: 15.26
# Environment solved in 3793 episodes!	Average Score: 15.26
# Episode 3896	Average Score: 15.26
# Environment solved in 3796 episodes!	Average Score: 15.26
# Episode 3897	Average Score: 15.26
# Environment solved in 3797 episodes!	Average Score: 15.26
# Episode 3898	Average Score: 15.31
# Environment solved in 3798 episodes!	Average Score: 15.31
# Episode 3899	Average Score: 15.40
# Environment solved in 3799 episodes!	Average Score: 15.40
# Episode 3900	Average Score: 15.39
# Episode 3901	Average Score: 15.45
# Environment solved in 3801 episodes!	Average Score: 15.45
# Episode 3904	Average Score: 15.52
# Environment solved in 3804 episodes!	Average Score: 15.52
# Episode 3905	Average Score: 15.55
# Environment solved in 3805 episodes!	Average Score: 15.55
# Episode 3906	Average Score: 15.63
# Environment solved in 3806 episodes!	Average Score: 15.63
# Episode 3912	Average Score: 15.63
# Environment solved in 3812 episodes!	Average Score: 15.63
# Episode 3913	Average Score: 15.64
# Environment solved in 3813 episodes!	Average Score: 15.64
# Episode 3921	Average Score: 15.68
# Environment solved in 3821 episodes!	Average Score: 15.68
# Episode 3922	Average Score: 15.69
# Environment solved in 3822 episodes!	Average Score: 15.69
# Episode 4000	Average Score: 15.04

# %%
import torch
from lib.agents import AgentExerperienceReplay, AgentPrioritizedExperience

from lib.dqn import dqn

import matplotlib.pyplot as plt
# %matplotlib inline
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
print('States look like:', state)
state_size = len(state)
print('States have length:', state_size)

def create_model(state_size, action_size, seed):
    return 

agent = AgentPrioritizedExperience(state_size=state_size, action_size=action_size, seed=0, 
                                   prioritized_experience=True, 
                                   compute_weights=True,
                                  )

scores = dqn(env, brain_name, agent, n_episodes=4000, checkpoint=13)









# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

agent.save_model('ddqn_with_prioritized_experiences_qnetwork')
